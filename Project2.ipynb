# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('zno3data.asc',delimiter=',',usecols=[0,2],skipinitialspace=True).dropna(axis=1, how='all')
print(df)
# Out:
#      Wavelength  Intensity
# 0     531.77081   393210.0
# 1     531.84149   393210.0
# 2     531.91216   168125.0
# 3     531.98284    17131.0
# 4     532.05351     7678.0
# ..          ...        ...
# 571   571.76997     1257.0
# 572   571.83939     1289.0
# 573   571.90881     1311.0
# 574   571.97823     1260.0
# 575   572.04764     1577.0
#
# [576 rows x 2 columns]

# %%
df.plot(x='Wavelength',y='Intensity')
# Out:
# <AxesSubplot:xlabel='Wavelength'>
